# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from LoadData import loaddata, filter_zeroes

simulation_names = ['Eagle', 'Illustris', 'IllustrisTNG', 'Mufasa', 'Simba', 'SC-Sam', 'UniverseMachine', 'Fire-2', 'g14', 'Marvel_JL']
data = loaddata(simulation_names)

inputHistories = np.array([element[0] for element in data])
mass_presentsfr = np.array([element[1] for element in data])
labels = np.array([element[2] for element in data])

for i in range(len(labels)):
    if labels[i] == 'Eagle':
        labels[i] = 0
    elif labels[i] == 'Illustris':
        labels[i] = 1
    elif labels[i] == 'IllustrisTNG':
        labels[i] = 2
    elif labels[i] == 'Mufasa':
        labels[i] = 3
    elif labels[i] == 'Simba':
        labels[i] = 4
    elif labels[i] == 'SC-Sam':
        labels[i] = 5
    elif labels[i] == 'UniverseMachine':
        labels[i] = 6
    elif labels[i] == 'Fire-2':
        labels[i] = 7
    elif labels[i] == 'g14':
        labels[i] = 8
    elif labels[i] == 'Marvel_JL':
        labels[i] = 9
labels = np.array(labels).astype('float32')


filtered_inputHistories, filtered_mass_presentsfr, filtered_labels = filter_zeroes(inputHistories, mass_presentsfr, labels)

# %%
filtered_inputHistories.shape
# Out:
# (63110, 139)

# %%
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(filtered_inputHistories, filtered_labels, test_size=0.2, random_state=42)

# Normalize the star formation histories
X_train = [(sfh / (np.trapz(sfh)) * 500) for sfh in X_train]  # Normalize SFH
X_test = [(sfh / (np.trapz(sfh)) * 500) for sfh in X_test]    # Normalize SFH

X_train = np.array(X_train)
X_test = np.array(X_test)

# Further split the training data into 80% (64%) training and 20% (16%) validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader, TensorDataset

device = "cpu"
print(f"Using {device} device")

X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32) 
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.float32)
# Out:
# Using cpu device

# %% [markdown]
# **The first 100 SFHs:**

# %%
for i in range(100):
    plt.plot(X_train_tensor[i])

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR

# Define the neural network
class ConvAutoencoder(nn.Module):
    def __init__(self):
        super(ConvAutoencoder, self).__init__()
        # Encoder
        self.conv1 = nn.Conv1d(in_channels=1, out_channels=16, kernel_size=4, padding=1)  
        self.conv2 = nn.Conv1d(in_channels=16, out_channels=16, kernel_size=4, padding=1)
        self.conv3 = nn.Conv1d(in_channels=16, out_channels=16, kernel_size=5, padding=1)
        self.conv4 = nn.Conv1d(in_channels=16, out_channels=16, kernel_size=5, padding=1)  
        self.pool = nn.MaxPool1d(2, 2)  
        self.fc1 = nn.Linear(16 * 7, 64)  
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, 4)
        
        # Decoder
        self.fc4 = nn.Linear(4, 32)
        self.fc5 = nn.Linear(32, 64)
        self.fc6 = nn.Linear(64, 16 * 7)
        self.deconv1 = nn.ConvTranspose1d(in_channels=16, out_channels=16, kernel_size=4, stride=2)
        self.deconv2 = nn.ConvTranspose1d(in_channels=16, out_channels=16, kernel_size=4, stride=2)
        self.deconv3 = nn.ConvTranspose1d(in_channels=16, out_channels=16, kernel_size=3, stride=2)
        self.deconv4 = nn.ConvTranspose1d(in_channels=16, out_channels=1, kernel_size=3, stride=2)
        
    def encoder(self, x):
        x = self.pool(torch.relu(self.conv1(x)))
        x = self.pool(torch.relu(self.conv2(x)))
        x = self.pool(torch.relu(self.conv3(x)))
        x = self.pool(torch.relu(self.conv4(x)))  
        x = x.view(-1, 16 * 7)  # Matching new dimensions after convolutions and pooling
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        encoded = torch.relu(self.fc3(x))
        return encoded

    def decoder(self, x):
        x = torch.relu(self.fc4(x))
        x = torch.relu(self.fc5(x))
        x = torch.relu(self.fc6(x))
        x = x.view(-1, 16, 7)
        x = torch.relu(self.deconv1(x))
        x = torch.relu(self.deconv2(x))
        x = torch.relu(self.deconv3(x))
        x = torch.relu(self.deconv4(x))
        return x

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

# Create the model instance
AE = ConvAutoencoder().to(device)

# Define the loss function and optimizer
criterion = nn.MSELoss()  # Assuming regression task with MSE loss
optimizer = optim.Adam(AE.parameters(), lr=0.001)
scheduler = StepLR(optimizer, step_size=100, gamma=0.9)

# Create a DataLoader for batch processing
dataset = TensorDataset(X_train_tensor.unsqueeze(1), y_train_tensor)
dataloader = DataLoader(dataset, batch_size=200, shuffle=True)

val_dataset = TensorDataset(X_val_tensor.unsqueeze(1), y_val_tensor)
val_dataloader = DataLoader(val_dataset, batch_size=200, shuffle=False)

# %%
print(AE)
# Out:
# ConvAutoencoder(
#   (conv1): Conv1d(1, 16, kernel_size=(4,), stride=(1,), padding=(1,))
#   (conv2): Conv1d(16, 16, kernel_size=(4,), stride=(1,), padding=(1,))
#   (conv3): Conv1d(16, 16, kernel_size=(5,), stride=(1,), padding=(1,))
#   (conv4): Conv1d(16, 16, kernel_size=(5,), stride=(1,), padding=(1,))
#   (pool): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=112, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=32, bias=True)
#   (fc3): Linear(in_features=32, out_features=4, bias=True)
#   (fc4): Linear(in_features=4, out_features=32, bias=True)
#   (fc5): Linear(in_features=32, out_features=64, bias=True)
#   (fc6): Linear(in_features=64, out_features=112, bias=True)
#   (deconv1): ConvTranspose1d(16, 16, kernel_size=(4,), stride=(2,))
#   (deconv2): ConvTranspose1d(16, 16, kernel_size=(4,), stride=(2,))
#   (deconv3): ConvTranspose1d(16, 16, kernel_size=(3,), stride=(2,))
#   (deconv4): ConvTranspose1d(16, 1, kernel_size=(3,), stride=(2,))
# )

# %%
# Training loop
num_epochs = 800
losses = [] # To store training losses
val_losses = []  # To store validation losses

for epoch in range(num_epochs):
    loss = 0.0
    for data in dataloader:
        inputs, _ = data
        optimizer.zero_grad()
        outputs = AE(inputs)
        curr_loss = criterion(outputs, inputs) # Comparing output to input for autoencoder
        curr_loss.backward()
        optimizer.step()
        loss += curr_loss.item()

    loss /= len(dataloader)
    losses.append(loss)
    
    AE.eval()
    val_loss = 0.0
    with torch.no_grad():
        for data in val_dataloader:
            val_inputs, _ = data
            val_outputs = AE(val_inputs)
            val_loss += criterion(val_outputs, val_inputs).item() # Comparing validation output and input
    
    val_loss /= len(val_dataloader)
    val_losses.append(val_loss)
    

    if epoch % 10 == 0:
        print(f'Epoch [{epoch}/{num_epochs}], Training Loss: {loss:.4f}, Val Loss: {val_loss:.4f}')
    # tell scheduler to consider updating learning rate
    scheduler.step()

print('Training complete')
# Out:
# Epoch [0/800], Training Loss: 9.4783, Val Loss: 7.9537
# Epoch [10/800], Training Loss: 3.3360, Val Loss: 3.2638
# Epoch [20/800], Training Loss: 3.2025, Val Loss: 3.1686
# Epoch [30/800], Training Loss: 3.1656, Val Loss: 3.1345
# Epoch [40/800], Training Loss: 3.1371, Val Loss: 3.0924
# Epoch [50/800], Training Loss: 3.1087, Val Loss: 3.0669
# Epoch [60/800], Training Loss: 3.0901, Val Loss: 3.0844
# Epoch [70/800], Training Loss: 3.0837, Val Loss: 3.0602
# Epoch [80/800], Training Loss: 3.0551, Val Loss: 3.0584
# Epoch [90/800], Training Loss: 3.0495, Val Loss: 3.0287
# Epoch [100/800], Training Loss: 3.0621, Val Loss: 3.0640
# Epoch [110/800], Training Loss: 3.0096, Val Loss: 3.0871
# Epoch [120/800], Training Loss: 3.0035, Val Loss: 3.0189
# Epoch [130/800], Training Loss: 2.9910, Val Loss: 3.0002
# Epoch [140/800], Training Loss: 2.9799, Val Loss: 2.9649
# Epoch [150/800], Training Loss: 2.9836, Val Loss: 2.9762
# Epoch [160/800], Training Loss: 2.9664, Val Loss: 2.9639
# Epoch [170/800], Training Loss: 2.9480, Val Loss: 2.9749
# Epoch [180/800], Training Loss: 2.9475, Val Loss: 2.9581
# Epoch [190/800], Training Loss: 2.9479, Val Loss: 2.9798
# Epoch [200/800], Training Loss: 2.9135, Val Loss: 2.9994
# Epoch [210/800], Training Loss: 2.9420, Val Loss: 2.9446
# Epoch [220/800], Training Loss: 2.9162, Val Loss: 2.9313
# Epoch [230/800], Training Loss: 2.9107, Val Loss: 2.9189
# Epoch [240/800], Training Loss: 2.7497, Val Loss: 2.7607
# Epoch [250/800], Training Loss: 2.6663, Val Loss: 2.6655
# Epoch [260/800], Training Loss: 2.6151, Val Loss: 2.6184
# Epoch [270/800], Training Loss: 2.6008, Val Loss: 2.6240
# Epoch [280/800], Training Loss: 2.6663, Val Loss: 2.5847
# Epoch [290/800], Training Loss: 2.5744, Val Loss: 2.5794
# Epoch [300/800], Training Loss: 2.5253, Val Loss: 2.5270
# Epoch [310/800], Training Loss: 2.5161, Val Loss: 2.5297
# Epoch [320/800], Training Loss: 2.5262, Val Loss: 2.5471
# Epoch [330/800], Training Loss: 2.5041, Val Loss: 2.5358
# Epoch [340/800], Training Loss: 2.5028, Val Loss: 2.5159
# Epoch [350/800], Training Loss: 2.4812, Val Loss: 2.4869
# Epoch [360/800], Training Loss: 2.4910, Val Loss: 2.4913
# Epoch [370/800], Training Loss: 2.5062, Val Loss: 2.5112
# Epoch [380/800], Training Loss: 2.4620, Val Loss: 2.4809
# Epoch [390/800], Training Loss: 2.4742, Val Loss: 2.4861
# Epoch [400/800], Training Loss: 2.4455, Val Loss: 2.4816
# Epoch [410/800], Training Loss: 2.4360, Val Loss: 2.4604
# Epoch [420/800], Training Loss: 2.4403, Val Loss: 2.4875
# Epoch [430/800], Training Loss: 2.4371, Val Loss: 2.4698
# Epoch [440/800], Training Loss: 2.3633, Val Loss: 2.4042
# Epoch [450/800], Training Loss: 2.3445, Val Loss: 2.3371
# Epoch [460/800], Training Loss: 2.3161, Val Loss: 2.3251
# Epoch [470/800], Training Loss: 2.2589, Val Loss: 2.2853
# Epoch [480/800], Training Loss: 2.2557, Val Loss: 2.2787
# Epoch [490/800], Training Loss: 2.2460, Val Loss: 2.2790
# Epoch [500/800], Training Loss: 2.2319, Val Loss: 2.2547
# Epoch [510/800], Training Loss: 2.2110, Val Loss: 2.2402
# Epoch [520/800], Training Loss: 2.3081, Val Loss: 2.3234
# Epoch [530/800], Training Loss: 2.2490, Val Loss: 2.2640
# Epoch [540/800], Training Loss: 2.2136, Val Loss: 2.2354
# Epoch [550/800], Training Loss: 2.2061, Val Loss: 2.2250
# Epoch [560/800], Training Loss: 2.1988, Val Loss: 2.2319
# Epoch [570/800], Training Loss: 2.1901, Val Loss: 2.2161
# Epoch [580/800], Training Loss: 2.1775, Val Loss: 2.2031
# Epoch [590/800], Training Loss: 2.1885, Val Loss: 2.2083
# Epoch [600/800], Training Loss: 2.1744, Val Loss: 2.1994
# Epoch [610/800], Training Loss: 2.1448, Val Loss: 2.1914
# Epoch [620/800], Training Loss: 2.1710, Val Loss: 2.1890
# Epoch [630/800], Training Loss: 2.1762, Val Loss: 2.2285
# Epoch [640/800], Training Loss: 2.1387, Val Loss: 2.1852
# Epoch [650/800], Training Loss: 2.1305, Val Loss: 2.2050
# Epoch [660/800], Training Loss: 2.1268, Val Loss: 2.1706
# Epoch [670/800], Training Loss: 2.1240, Val Loss: 2.1734
# Epoch [680/800], Training Loss: 2.1150, Val Loss: 2.1668
# Epoch [690/800], Training Loss: 2.1091, Val Loss: 2.1599
# Epoch [700/800], Training Loss: 2.1106, Val Loss: 2.1622
# Epoch [710/800], Training Loss: 2.1108, Val Loss: 2.1640
# Epoch [720/800], Training Loss: 2.1013, Val Loss: 2.1587
# Epoch [730/800], Training Loss: 2.0958, Val Loss: 2.1606
# Epoch [740/800], Training Loss: 2.0958, Val Loss: 2.1575
# Epoch [750/800], Training Loss: 2.0926, Val Loss: 2.1574
# Epoch [760/800], Training Loss: 2.0905, Val Loss: 2.1621
# Epoch [770/800], Training Loss: 2.0998, Val Loss: 2.1637
# Epoch [780/800], Training Loss: 2.0922, Val Loss: 2.1575
# Epoch [790/800], Training Loss: 2.1028, Val Loss: 2.1594
# Training complete

# %%
i = 2132
plt.plot(AE(X_val_tensor[i].unsqueeze(0).unsqueeze(0))[0][0].detach().numpy())
plt.plot(X_val_tensor[i].unsqueeze(0).unsqueeze(0)[0][0].detach().numpy())
plt.legend(['Reconstructed', 'Original'])

# %%
plt.plot(losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.ylim(0.75,3)
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

np.save('AE Losses/4lat2.159loss.npy', val_losses)

# %%
torch.save(AE, 'AE Models/4lat2.159loss.pth')

# %%
generated_SFHs = AE(X_test_tensor.unsqueeze(1))
real_SFHs = X_test_tensor.unsqueeze(1)

# %%
# Calculate residuals
residuals = (generated_SFHs - real_SFHs).detach().numpy().squeeze()

# Create time axis
time_axis = np.tile(np.arange(residuals.shape[1]), residuals.shape[0])

# Flatten the residuals
residuals_flat = residuals.flatten()

# Create a 2D histogram
plt.figure(figsize=(10, 6))
plt.hist2d(time_axis, residuals_flat, bins=[139, 200], cmap='plasma')
plt.ylim(-10,10)
plt.colorbar(label='Counts')
plt.xlabel('Time step (100 Myr)')
plt.ylabel('Residual')
plt.title('Residuals of SFRs over Time')
plt.show()

# %%
plt.hist([np.mean(residual) for residual in residuals], bins=150)
plt.xlabel('Mean Residual')
plt.ylabel('Counts')
plt.title('Mean Residuals of SFHs')
plt.xlim(-0.5, 0.5)
plt.show()

# %%
AE = torch.load('AE Models/16lat1.269loss.pth')
print(AE)
# Out:
# ConvAutoencoder(
#   (conv1): Conv1d(1, 16, kernel_size=(4,), stride=(1,), padding=(1,))
#   (conv2): Conv1d(16, 16, kernel_size=(4,), stride=(1,), padding=(1,))
#   (conv3): Conv1d(16, 16, kernel_size=(5,), stride=(1,), padding=(1,))
#   (conv4): Conv1d(16, 16, kernel_size=(5,), stride=(1,), padding=(1,))
#   (pool): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=112, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=32, bias=True)
#   (fc3): Linear(in_features=32, out_features=16, bias=True)
#   (fc4): Linear(in_features=16, out_features=32, bias=True)
#   (fc5): Linear(in_features=32, out_features=64, bias=True)
#   (fc6): Linear(in_features=64, out_features=112, bias=True)
#   (deconv1): ConvTranspose1d(16, 16, kernel_size=(4,), stride=(2,))
#   (deconv2): ConvTranspose1d(16, 16, kernel_size=(4,), stride=(2,))
#   (deconv3): ConvTranspose1d(16, 16, kernel_size=(3,), stride=(2,))
#   (deconv4): ConvTranspose1d(16, 1, kernel_size=(3,), stride=(2,))
# )

# %%
all_data_tensor = torch.tensor(filtered_inputHistories, dtype=torch.float32)
all_labels_tensor = torch.tensor(filtered_labels, dtype=torch.float32)
latent_space = AE.encoder(all_data_tensor.unsqueeze(1)).detach().numpy()

# %%
import umap
reducer = umap.UMAP(n_components=2, min_dist=1, n_neighbors=50)
embedding = reducer.fit_transform(latent_space)
embedding.shape
# Out:
# (63110, 2)

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = ['Eagle', 'Illustris', 'IllustrisTNG', 'Mufasa', 'Simba', 'SC-Sam', 'UniverseMachine', 'Fire-2', 'g14', 'Marvel JL']

plt.scatter(embedding[:, 0], embedding[:, 1], c=all_labels_tensor, cmap='Spectral', s=0.05)
plt.gca().set_aspect('equal', 'datalim')

# Create a colorbar
cbar = plt.colorbar(boundaries=np.arange(11)-0.5, ticks=np.arange(10))

# Set the colorbar labels
cbar.ax.set_yticklabels(labels)

plt.title('UMAP projection of the latent space', fontsize=10)
plt.show()

# %%
# Left from 8 parameters model
for i in range(-5, 15):
    latent_params = get_ah_from_umap(i,-5, embedding, latent_space) # Extracting SFH parameters from UMAP space to see interesting structures!

# %%
from scipy.spatial import distance

def get_ah_from_umap(x, y, embedding: np.ndarray, latent_space: np.ndarray):
    """
    Function to get the latent parameters of the nearest point in the latent space to the given UMAP coordinates
    """
    input_coord = np.array([x, y])  # replace x, y with the actual coordinates

    distances = distance.cdist([input_coord], embedding, 'euclidean')
    nearest_index = np.argmin(distances)
    latent_params = latent_space[nearest_index]

    extracted_sfh = AE.decoder(torch.tensor(latent_params)).detach().numpy().flatten()
    plt.plot(extracted_sfh)

# %%
curve4lat2159loss = np.load('AE Losses/4lat2.159loss.npy')
curve8lat2145loss = np.load('AE Losses/8lat2.145loss.npy')
curve16lat1269loss = np.load('AE Losses/16lat1.269loss.npy')
curve32lat0917loss = np.load('AE Losses/32lat0.917loss.npy')
plt.plot(curve4lat2159loss, label='4 Latent Parameters')
plt.plot(curve8lat2145loss, label='8 Latent Parameters')
plt.plot(curve16lat1269loss, label='16 Latent Parameters')
plt.plot(curve32lat0917loss, label='32 Latent Parameters')
plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.legend()

# %%
curve8lat2145loss = np.load('AE Losses/8lat2.145loss.npy')
curve8lat2145loss
# Out:
# array([5.44432844, 3.93259651, 3.56176023, 3.41722233, 3.3366771 ,
#        3.34118881, 3.25268758, 3.28060683, 3.19310415, 3.21766437,
#        3.21062712, 3.15101704, 3.09620997, 3.13326688, 3.085326  ,
#        3.06343155, 3.04228746, 2.97597524, 2.92528886, 2.87991661,
#        2.82865929, 2.84638565, 2.79020855, 2.74146172, 2.72402452,
#        2.73895909, 2.70688171, 2.73799432, 2.76521257, 2.67793193,
#        2.68787398, 2.67000969, 2.70595916, 2.65267933, 2.68089031,
#        2.64332989, 2.6445162 , 2.70227995, 2.64178756, 2.63718934,
#        2.70565818, 2.61541991, 2.62548835, 2.6112186 , 2.59067748,
#        2.63207396, 2.61961343, 2.61323864, 2.60737028, 2.60041199,
#        2.58957515, 2.59088122, 2.58351601, 2.60493699, 2.56751022,
#        2.61449034, 2.57280116, 2.63017686, 2.59313715, 2.65874732,
#        2.56845692, 2.58320976, 2.57039678, 2.55271564, 2.53816091,
#        2.56508595, 2.54140222, 2.53897516, 2.54944109, 2.53805818,
#        2.55043844, 2.53726183, 2.55174091, 2.54236068, 2.54598695,
#        2.55239595, 2.52112196, 2.542819  , 2.55286222, 2.49936633,
#        2.48673771, 2.4560866 , 2.42784063, 2.41000811, 2.42506882,
#        2.39536976, 2.38515362, 2.36916059, 2.37948651, 2.34475988,
#        2.36578016, 2.34010281, 2.33025765, 2.326828  , 2.32271197,
#        2.35879239, 2.32784536, 2.32602297, 2.37496382, 2.33081819,
#        2.32156538, 2.30706581, 2.28334275, 2.2865675 , 2.2807539 ,
#        2.28742131, 2.30332217, 2.27268793, 2.29274211, 2.33424671,
#        2.26799146, 2.275784  , 2.2858884 , 2.27191042, 2.265365  ,
#        2.289765  , 2.26627787, 2.27727091, 2.32785464, 2.26889812,
#        2.32568246, 2.26699014, 2.24405328, 2.26291352, 2.25926442,
#        2.28366029, 2.25478154, 2.27472564, 2.29651431, 2.27628228,
#        2.25308214, 2.24968752, 2.272448  , 2.26494623, 2.27937038,
#        2.23934435, 2.23521981, 2.24357182, 2.24426147, 2.25246167,
#        2.27101843, 2.3746111 , 2.26170341, 2.25021702, 2.24730237,
#        2.24991705, 2.22981388, 2.24118559, 2.2783364 , 2.25975481,
#        2.22185058, 2.24855547, 2.38126377, 2.24310269, 2.22189467,
#        2.25708539, 2.24636565, 2.24035921, 2.26385285, 2.23296977,
#        2.26014447, 2.23625166, 2.23068747, 2.23973912, 2.27868581,
#        2.28468056, 2.22892437, 2.24416607, 2.20852793, 2.2132277 ,
#        2.21154914, 2.22990352, 2.234754  , 2.23179506, 2.228463  ,
#        2.22390615, 2.20622956, 2.21230925, 2.22471841, 2.23184777,
#        2.22397246, 2.2201452 , 2.24965002, 2.24566884, 2.2265134 ,
#        2.21632108, 2.21431082, 2.22217647, 2.2343924 , 2.22377522,
#        2.20897882, 2.20441522, 2.20624111, 2.21926533, 2.22493408,
#        2.21281406, 2.24628075, 2.22585759, 2.20470093, 2.21372583,
#        2.23707004, 2.20409075, 2.21931647, 2.21860433, 2.20104313,
#        2.21853094, 2.20548734, 2.19816017, 2.20032157, 2.22779547,
#        2.25677718, 2.23038552, 2.23576756, 2.2183529 , 2.22067529,
#        2.2185989 , 2.19258802, 2.20821892, 2.19029046, 2.22276625,
#        2.21257108, 2.20897102, 2.20142684, 2.20269353, 2.1998519 ,
#        2.19063403, 2.3063321 , 2.19336167, 2.19302683, 2.19891572,
#        2.19765485, 2.19982516, 2.19532228, 2.2000853 , 2.19327363,
#        2.19787097, 2.18868387, 2.37257882, 2.20804609, 2.20266673,
#        2.20248858, 2.18803644, 2.21917292, 2.21008667, 2.20164409,
#        2.18658743, 2.24650339, 2.18781925, 2.19794652, 2.19398916,
#        2.18469981, 2.19383361, 2.1975429 , 2.23017478, 2.23354913,
#        2.19821899, 2.22995327, 2.20452608, 2.18668124, 2.20924744,
#        2.228515  , 2.1896695 , 2.20211576, 2.19933317, 2.21830985,
#        2.1908477 , 2.17458028, 2.18777243, 2.18245956, 2.1936846 ,
#        2.1847157 , 2.19302515, 2.19764068, 2.19749798, 2.27403162,
#        2.26616793, 2.29220023, 2.25395718, 2.20004196, 2.21862983,
#        2.18303193, 2.18774283, 2.20479871, 2.19912795, 2.18339333,
#        2.20399327, 2.22082487, 2.18472068, 2.18472491, 2.20122941,
#        2.17550855, 2.184665  , 2.2177101 , 2.22482909, 2.20703152,
#        2.20263066, 2.19684536, 2.18857149, 2.18555481, 2.20209627,
#        2.18372748, 2.17057095, 2.1756256 , 2.19162896, 2.19864218,
#        2.17440104, 2.1819536 , 2.1835781 , 2.17813712, 2.18852294,
#        2.20701593, 2.19501463, 2.17232324, 2.19020039, 2.18307933,
#        2.17602141, 2.17942076, 2.16389055, 2.18582312, 2.2238407 ,
#        2.17335495, 2.2059422 , 2.17007088, 2.15955885, 2.17728746,
#        2.17178765, 2.18859437, 2.18201622, 2.21790202, 2.16759821,
#        2.17523506, 2.16894325, 2.21854604, 2.2217139 , 2.18696815,
#        2.16185178, 2.16967939, 2.18361063, 2.18186504, 2.19651144,
#        2.16555008, 2.21673592, 2.19718462, 2.19342261, 2.17743258,
#        2.18192634, 2.18405613, 2.18588149, 2.1600374 , 2.23931745,
#        2.17369136, 2.19714914, 2.20367182, 2.19054528, 2.17653444,
#        2.21215199, 2.21211083, 2.24457739, 2.18514755, 2.17845651,
#        2.17646882, 2.18115742, 2.19582214, 2.16963234, 2.17646915,
#        2.17733108, 2.17923673, 2.16588099, 2.17832947, 2.17339806,
#        2.19587854, 2.17049889, 2.18513724, 2.17019509, 2.20604762,
#        2.1869685 , 2.31497362, 2.18798386, 2.18000712, 2.1644996 ,
#        2.18647736, 2.2188802 , 2.18113256, 2.16379556, 2.17703981,
#        2.18614363, 2.17828625, 2.16181035, 2.59953112, 2.41699252,
#        2.17654866, 2.18494237, 2.17851955, 2.19236923, 2.1680539 ,
#        2.17840029, 2.16199868, 2.17154959, 2.18439227, 2.16314442,
#        2.16860557, 2.16572537, 2.15773499, 2.1579986 , 2.17586545,
#        2.16391552, 2.16416469, 2.17940489, 2.20306282, 2.16532451,
#        2.16283275, 2.17593565, 2.17852272, 2.16540218, 2.16136952,
#        2.15330849, 2.1669755 , 2.15327053, 2.17946945, 2.18737467,
#        2.15793989, 2.16141521, 2.15402223, 2.26984353, 2.15400904,
#        2.16129985, 2.17764378, 2.17539149, 2.18929424, 2.17760601,
#        2.16136955, 2.17527416, 2.15675236, 2.19230325, 2.16106535,
#        2.15773739, 2.15134292, 2.16141329, 2.1960901 , 2.16893316,
#        2.2893783 , 2.15567596, 2.15465487, 2.19661811, 2.15535123,
#        2.15560584, 2.18605422, 2.16358516, 2.17045458, 2.15808933,
#        2.21847481, 2.16000307, 2.16242046, 2.16419155, 2.18694834,
#        2.1598356 , 2.17668061, 2.16946963, 2.2000071 , 2.16686301,
#        2.17343997, 2.14814124, 2.16306933, 2.1811668 , 2.18266427,
#        2.20303244, 2.16091812, 2.18745554, 2.1763043 , 2.16664713,
#        2.14744303, 2.15321532, 2.18125534, 2.18444461, 2.18856639,
#        2.16919363, 2.15165656, 2.15336891, 2.14762718, 2.15800427,
#        2.15702446, 2.17133351, 2.18316449, 2.20539937, 2.18349946,
#        2.1584638 , 2.18826917, 2.17126417, 2.17226467, 2.16995372,
#        2.16445315, 2.15207894, 2.16324552, 2.14418209, 2.1534444 ,
#        2.1513311 , 2.14320118, 2.19061554, 2.15569083, 2.17124327,
#        2.17056984, 2.16295153, 2.14454952, 2.1371129 , 2.16537743,
#        2.16378751, 2.14802926, 2.14756107, 2.1829004 , 2.1564492 ,
#        2.27212923, 2.1474668 , 2.14644193, 2.14805579, 2.16020096,
#        2.23607575, 2.15188528, 2.14335972, 2.15424078, 2.14123382,
#        2.1498336 , 2.16298428, 2.14780078, 2.15422016, 2.14508222,
#        2.16254446, 2.13654713, 2.14385041, 2.15574982, 2.16529989,
#        2.1519774 , 2.15334634, 2.17335535, 2.16520022, 2.14933359,
#        2.14863412, 2.17647437, 2.16574652, 2.15602564, 2.14981277,
#        2.14164786, 2.18859279, 2.14764046, 2.14971216, 2.16351372,
#        2.1478263 , 2.15416015, 2.15663027, 2.1746504 , 2.15305506,
#        2.16160897, 2.15718529, 2.14138928, 2.13714812, 2.15774665,
#        2.14179037, 2.14496372, 2.13429488, 2.13767145, 2.16917932,
#        2.14279045, 2.14481971, 2.15043712, 2.14620741, 2.14628311,
#        2.14194769, 2.15837146, 2.14841299, 2.16054808, 2.17260595,
#        2.14712547, 2.14635772, 2.15923154, 2.13724546, 2.13788205,
#        2.15568246, 2.14407261, 2.14726744, 2.1442582 , 2.16122106,
#        2.14769688, 2.13696977, 2.14995869, 2.15984451, 2.13901558,
#        2.2175522 , 2.16039555, 2.13107666, 2.13937747, 2.13010752,
#        2.14323914, 2.14629354, 2.14773176, 2.1469409 , 2.13704715,
#        2.15543625, 2.14217621, 2.15615601, 2.19627706, 2.14801115,
#        2.15139505, 2.14806501, 2.1354556 , 2.14481653, 2.1540847 ,
#        2.14804912, 2.16789046, 2.13557594, 2.13300231, 2.14470439,
#        2.13943153, 2.1384913 , 2.16639923, 2.14740673, 2.15839349,
#        2.13194361, 2.15350262, 2.13860256, 2.14824365, 2.14699417,
#        2.16230196, 2.13726714, 2.13768224, 2.13610076, 2.13161565,
#        2.14502142, 2.16895311, 2.14275463, 2.17105954, 2.19442642,
#        2.18170362, 2.16060283, 2.13654718, 2.14766799, 2.14394815,
#        2.15303964, 2.14613639, 2.13937528, 2.15316269, 2.14019518,
#        2.13488844, 2.13860108, 2.14815256, 2.13271229, 2.13208419,
#        2.15499968, 2.13407895, 2.14516961, 2.13679779, 2.1299219 ,
#        2.14285393, 2.14782822, 2.1337921 , 2.12934595, 2.1274182 ,
#        2.13819449, 2.13427116, 2.1236334 , 2.12792244, 2.13342892,
#        2.12719264, 2.13481818, 2.16408683, 2.1330891 , 2.13850879,
#        2.14263514, 2.12689823, 2.13314515, 2.12950244, 2.1307545 ,
#        2.14856738, 2.13110875, 2.13060545, 2.13763978, 2.15323477,
#        2.1462209 , 2.1328577 , 2.1364441 , 2.14286904, 2.13612001,
#        2.13506624, 2.13924439, 2.12748093, 2.12080451, 2.12809971,
#        2.1300392 , 2.13673762, 2.14290347, 2.14550591, 2.13410741,
#        2.13862267, 2.12603629, 2.16975489, 2.12974683, 2.17698054,
#        2.13526699, 2.2463321 , 2.14999999, 2.15502396, 2.14796453,
#        2.15215336, 2.14953611, 2.17649734, 2.15079973, 2.13033294,
#        2.1405676 , 2.12653856, 2.14755252, 2.15926276, 2.14068791,
#        2.14693907, 2.13943278, 2.153842  , 2.13834448, 2.12431689,
#        2.12978052, 2.14659558, 2.1281463 , 2.12995499, 2.15405752,
#        2.12257158, 2.13178388, 2.12526845, 2.12782211, 2.13444918,
#        2.1339189 , 2.14054744, 2.130041  , 2.12553091, 2.12435498,
#        2.13459799, 2.1239879 , 2.12917436, 2.12797171, 2.13929584,
#        2.13230014, 2.14094691, 2.13776044, 2.1309236 , 2.16243307,
#        2.13840156, 2.153092  , 2.14744269, 2.12022293, 2.12347623,
#        2.14008351, 2.13331915, 2.13806171, 2.13578591, 2.12366684,
#        2.12995436, 2.13811532, 2.12940468, 2.13996222, 2.13209048,
#        2.12823091, 2.12152995, 2.1508496 , 2.12864726, 2.12357003,
#        2.1356538 , 2.15269602, 2.14966079, 2.1458742 , 2.13215063,
#        2.17152666, 2.13085827, 2.12704109, 2.13548778, 2.12628382,
#        2.13372169, 2.13961976, 2.13531441, 2.13038726, 2.12886599,
#        2.13760159, 2.14954449, 2.13708931, 2.15111402, 2.1303146 ,
#        2.12704617, 2.14010363, 2.12691439, 2.14805782, 2.12732432,
#        2.14026651, 2.13481296, 2.13592917, 2.13859086, 2.13788678,
#        2.14501149, 2.14607385, 2.13338265, 2.14885691, 2.13871799,
#        2.14817933, 2.16525041, 2.14160949, 2.13606211, 2.13475521])
